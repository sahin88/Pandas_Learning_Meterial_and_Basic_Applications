# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime.now()

df = web.DataReader("GOOGL", "iex", start, end)
#print(df)
df.plot()
plt.legend()
plt.show()
# Out:
# 2y
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bbecf07ff98d> in <module>()
#      12 df = web.DataReader("GOOGL", "iex", start, end)
#      13 #print(df)
# ---> 14 df.plot_date()
#      15 plt.legend()
#      16 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plot_date'

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

web_stats={'Days':[1,2,3,4,5,6],
           'Visitors':[43,53,34,45,64,34],
           'Bounce_Rate':[65,72,62,64,54,66],'hazreti':[0,0,0,0,0,0]}
df=pd.DataFrame(web_stats)
#print(df)
#print(df.head())
#print(df.tail())
#print(df.tail(2))
#print(df.set_index('Days'))
#print(df.head())
df.set_index('Days',inplace=True)

#print(df.head())

print(df.head())
# Out:
#       Visitors  Bounce_Rate  hazreti
# Days
# 1           43           65        0
# 2           53           72        0
# 3           34           62        0
# 4           45           64        0
# 5           64           54        0

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

web_stats={'Days':[1,2,3,4,5,6],
           'Visitors':[43,53,34,45,64,34],
           'Bounce_Rate':[65,72,62,64,54,66]}
df=pd.DataFrame(web_stats)
#print(df)
#print(df.head())
#print(df.tail())
#print(df.tail(2))
#print(df.set_index('Days'))
#print(df.head())
df.set_index('Days',inplace=True)

#print(df.head())

print(df.head())
# Out:
#       Visitors  Bounce_Rate
# Days
# 1           43           65
# 2           53           72
# 3           34           62
# 4           45           64
# 5           64           54

# %% [markdown]
# # Print of Spesific Column

# %%
print(df[['Visitors','Bounce_Rate','hazreti']])
# Out:
#       Visitors  Bounce_Rate  hazreti
# Days
# 1           43           65        0
# 2           53           72        0
# 3           34           62        0
# 4           45           64        0
# 5           64           54        0
# 6           34           66        0

# %%
print(df.Visitors)
# Out:
# Days
# 1    43
# 2    53
# 3    34
# 4    45
# 5    64
# 6    34
# Name: Visitors, dtype: int64

# %% [markdown]
# # Print of Spesific two Columns

# %%
print(df[['Visitors','Bounce_Rate']])
# Out:
#       Visitors  Bounce_Rate
# Days
# 1           43           65
# 2           53           72
# 3           34           62
# 4           45           64
# 5           64           54
# 6           34           66

# %% [markdown]
# # Inplace True and False

# %%
import pandas as pd

ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.shape
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# If  we call the table ,seems like as per above. If the first columns is drop by using drop functions, seems like following

# %%
ufo.drop('City',axis=1).head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# If we  call "ufo.head()" one more time, itseems that the first column is not  dropped, that happens becaufe of the function of "inflace=False"

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1, inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # How do I read tabular data file into pandas?

# %%
import pandas as pd
table=pd.read_table('http://bit.ly/chiporders')
table.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
users_columns=['user id','age','gender','occupation','zip_code']
table_1=pd.read_table('http://bit.ly/movieusers', sep='|', header=None,names=users_columns)
table_1.head()
# Out:
#    user id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# # How do I select  a panda Series from Data Frame ?

# %%
import pandas as pd
ufo= pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
ufo['location'] = ufo.City+',  '+ufo.State
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Ekleme cikarma yapilirken belirli bir columns köseli parantez icinde yazdirildigi zaman seri seklinde yazdirirlir. ama okunan datalar 'pd.read_csv' veya 'pd.read_table' Dataframe seklinde okunur   ekleme yapilirkende seri seklinde yazilir

# %% [markdown]
# # Why do some commands end with aranthesese why not the others?

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab7961a083cb> in <module>()
# ----> 1 movies=pd.read_csv('http://bit.ly/imdbratings')
#       2 movies.head()
#
# NameError: name 'pd' is not defined

# %%
movies.describe("3D objectjects")
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movieses)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.describe(include=['object'])
# Out:
#                  title content_rating  genre  \
# count              979            976    979
# unique             975             12     16
# top     Les Miserables              R  Drama
# freq                 2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %% [markdown]
# # How do I rename columns in Pandas DataFrame?

# %%
import pandas as pd 
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Color___Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo.index
# Out:
# RangeIndex(start=0, stop=18241, step=1)

# %% [markdown]
# # Changing the heading row method 2(Rename Command)

# %%
ufo.rename(columns={'Colors Reported':'Color___Reported'}, inplace=True)
ufo.head()
# Out:
#                    City Color___Reported Shape Reported State  \
# 0                Ithaca              NaN       TRIANGLE    NY
# 1           Willingboro              NaN          OTHER    NJ
# 2               Holyoke              NaN           OVAL    CO
# 3               Abilene              NaN           DISK    KS
# 4  New York Worlds Fair              NaN          LIGHT    NY
#
#               Time                   Location
# 0   6/1/1930 22:00                Ithaca,  NY
# 1  6/30/1930 20:00           Willingboro,  NJ
# 2  2/15/1931 14:00               Holyoke,  CO
# 3   6/1/1931 13:00               Abilene,  KS
# 4  4/18/1933 19:00  New York Worlds Fair,  NY

# %% [markdown]
# # Adding a new columns

# %%
ufo['Location'] = ufo.City+',  '+ ufo.State
ufo.head()
# Out:
#                    City Color___Reported Shape Reported State  \
# 0                Ithaca              NaN       TRIANGLE    NY
# 1           Willingboro              NaN          OTHER    NJ
# 2               Holyoke              NaN           OVAL    CO
# 3               Abilene              NaN           DISK    KS
# 4  New York Worlds Fair              NaN          LIGHT    NY
#
#               Time                   Location
# 0   6/1/1930 22:00                Ithaca,  NY
# 1  6/30/1930 20:00           Willingboro,  NJ
# 2  2/15/1931 14:00               Holyoke,  CO
# 3   6/1/1931 13:00               Abilene,  KS
# 4  4/18/1933 19:00  New York Worlds Fair,  NY

# %% [markdown]
# # Changing the headings row metod 1

# %%
ufos= ['City__', 'Color__Reported', 'Shape__Reported','State__','Time__']
ufo_1= pd.read_csv('http://bit.ly/uforeports', names=ufos,header=0)
ufo_1.head()
# Out:
#                  City__ Color__Reported Shape__Reported State__  \
# 0                Ithaca             NaN        TRIANGLE      NY
# 1           Willingboro             NaN           OTHER      NJ
# 2               Holyoke             NaN            OVAL      CO
# 3               Abilene             NaN            DISK      KS
# 4  New York Worlds Fair             NaN           LIGHT      NY
#
#             Time__
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.columns=ufo.columns.str.replace('-' ,' ')
ufo.columns
ufo.head()
# Out:
#      _ C _ i _ t _ y _   \
# 0                Ithaca
# 1           Willingboro
# 2               Holyoke
# 3               Abilene
# 4  New York Worlds Fair
#
#    _ C _ o _ l _ o _ r       _ R _ e _ p _ o _ r _ t _ e _ d _   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    _ S _ h _ a _ p _ e _   _ R _ e _ p _ o _ r _ t _ e _ d _   \
# 0                                           TRIANGLE
# 1                                              OTHER
# 2                                               OVAL
# 3                                               DISK
# 4                                              LIGHT
#
#    _ S _ t _ a _ t _ e _   _ T _ i _ m _ e _   \
# 0                      NY      6/1/1930 22:00
# 1                      NJ     6/30/1930 20:00
# ...

# %% [markdown]
# # How do i remove a column from Dataframe?

# %%
import pandas as pd
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
ufo.drop('City',axis=1, inplace=True)

# %% [markdown]
# # What do I need to  know  about pandas index?

# %%
import pandas as pd
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 6)

# %%
import pandas as pd 
movie=pd.read_csv('http://bit.ly/movieusers', header=None)
movie.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
movie.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-08c258555be2> in <module>()
# ----> 1 movie.shape
#
# NameError: name 'movie' is not defined

# %% [markdown]
# # How do I  remove columns from a Pandas Dataframe?

# %%
import pandas as pd
ufo= pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.drop('Colors Reported',axis=1, inplace=True)
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop(['City','State'], axis=1, inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#   Shape Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %% [markdown]
# # How  do I sort Pandas Dataseries or Series

# %%
import pandas as pd

# %%
movies= pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.sort_values('title')
# Out:
#      star_rating                                title content_rating  \
# 542          7.8                 (500) Days of Summer          PG-13
# 5            8.9                         12 Angry Men      NOT RATED
# 201          8.1                     12 Years a Slave              R
# 698          7.6                            127 Hours              R
# 110          8.3                2001: A Space Odyssey              G
# 910          7.5                                 2046              R
# 596          7.7                             21 Grams              R
# 624          7.7                            25th Hour              R
# 708          7.6                     28 Days Later...              R
# 60           8.5                             3 Idiots          PG-13
# 225          8.1                               3-Iron              R
# 570          7.8                                  300              R
# 555          7.8                         3:10 to Yuma              R
# ...

# %%
movies.sort_values(['title','duration'])
# Out:
#      star_rating                                title content_rating  \
# 542          7.8                 (500) Days of Summer          PG-13
# 5            8.9                         12 Angry Men      NOT RATED
# 201          8.1                     12 Years a Slave              R
# 698          7.6                            127 Hours              R
# 110          8.3                2001: A Space Odyssey              G
# 910          7.5                                 2046              R
# 596          7.7                             21 Grams              R
# 624          7.7                            25th Hour              R
# 708          7.6                     28 Days Later...              R
# 60           8.5                             3 Idiots          PG-13
# 225          8.1                               3-Iron              R
# 570          7.8                                  300              R
# 555          7.8                         3:10 to Yuma              R
# ...

# %% [markdown]
# # How do i  filter rows of pandas Dataframe by column value?

# %%
import pandas as pd

# %%
movie=pd.read_csv('http://bit.ly/imdbratings')

# %%
movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
a=movie.duration >143
a.tail()
# Out:
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, dtype: bool

# %%
b=movie[a]
b.head()
# Out:
#    star_rating                           title content_rating    genre  \
# 1          9.2                   The Godfather              R    Crime
# 2          9.1          The Godfather: Part II              R    Crime
# 3          9.0                 The Dark Knight          PG-13   Action
# 4          8.9                    Pulp Fiction              R    Crime
# 6          8.9  The Good, the Bad and the Ugly      NOT RATED  Western
#
#    duration                                        actors_list
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 6       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...

# %%
type(True)
# Out:
# bool

# %%
boeleans=[]
for a in movies.duration:
    if a >= 200:
        boeleans.append(True)
    else:
        boeleans.append(False)

# %%
boeleans[0:5]
# Out:
# [False, False, True, False, False]

# %%
is_long= pd.Series(boeleans)

# %%
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
movies[is_long]['genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# # Not

# %% [markdown]
# pandadaki satirlar 'False'veya 'True' methoduna göre calisir eger  degerde bulunan sayi 'True' ise  gösteriri yanlis ise o islemin bulundugu satiri atlatir.

# %% [markdown]
# yukarida yapilan islemde duration ile ilgili kisim liste seklinde ilk önce okundu= movie.duration

# %% [markdown]
# daha sonra okunan degerler karsilastirma ile karsilastirildi  ve dogru olanlar 'True' olarak atandi

# %% [markdown]
# yanlis olanlar ise 'False'olarak atandi  ve bir dataframe eklendi

# %% [markdown]
# daha sonra bu data frame pd.Series[Dataframe listesinin ismi olarak eklendi ]  ve data frame seriye cevrildi

# %% [markdown]
#  daha sonra bu seri movei=pd.read_csv('http://bit.ly/imdbratins') tanimlanan movie nin icine köseli parantez seklin ve tirnak
#  isareti kullanilmadan yazildi ve program calistirildiginda listenin icerisindeki 'True' komutlarina denk gelen degerler gösterildi 'False'olanlar  gösterilmedi.

# %%
import pandas as pd
movie=pd.read_csv('http://bit.ly/imdbratings')
movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie.loc[movie.duration >= 200,'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movie[movie.duration>=200].genre
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movie[movie.duration>=200]['genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# # How do I apply multiple filter criteria to a pandas Dataframe?

# %%
import pandas as pd
movie=pd.read_csv('http://bit.ly/imdbratings')
movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie[movie.duration <200]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# ...

# %%
movie[(movie.duration>=200) & ( movie.genre =='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %% [markdown]
# # What about reading only two columns o spesific rows?

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports',  usecols=['City','State'])
ufo.columns
# Out:
# Index(['City', 'State'], dtype='object')

# %% [markdown]
# baska bir method daha var ondada kolum numarasini baslangic ve bitis olarak göstermek

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports',  usecols=[0,3])
ufo.columns
# Out:
# Index(['City', 'State'], dtype='object')

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports', nrows=3)
ufo.head()
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# # How do Dataframes and Series work with regard to selecting indivudual entries and iterations?

# %%
for c in ufo.City:
    print(c)
# Out:
# Ithaca
# Willingboro
# Holyoke

# %%
for index, row in ufo.iterrows():
    print(index, row.City,row.State)
# Out:
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO

# %% [markdown]
# # How can I drop the nun numeric columns?

# %%
import pandas as pd
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(include=['object'])
# Out:
#            country continent
# count          193       193
# unique         193         6
# top     Uzbekistan    Africa
# freq             1        53

# %% [markdown]
# # How do I use axis paramaters?

# %%
import pandas as pd
drinks= pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('country', axis =1).head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop(3,axis=0).head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=0)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %% [markdown]
# axis bize yön konusunda yardimci olur

# %% [markdown]
# # How do I use string method in pandas?

# %%
import pandas as pd

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders[orders.item_name.str.contains('Chicken')].head() # bir colondaki olan seyleri kiyaslamasini yapar
# Out:
#     order_id  quantity             item_name  \
# 4          2         2          Chicken Bowl
# 5          3         1          Chicken Bowl
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
# 13         7         1          Chicken Bowl
#
#                                    choice_description item_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25

# %% [markdown]
# # How I can change the datatype of pandas Series?

# %%
import pandas as pd
drinks= pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks['beer_servings']
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
# 5      102
# 6      193
# 7       21
# 8      261
# 9      279
# 10      21
# 11     122
# 12      42
# 13       0
# 14     143
# 15     142
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21      76
# 22     173
# 23     245
# 24      31
# 25     231
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    128
# 164     90
# 165    152
# 166    185
# 167      5
# 168      2
# 169     99
# 170    106
# 171      1
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     19
# 178      6
# 179     45
# 180    206
# 181     16
# 182    219
# 183     36
# 184    249
# 185    115
# 186     25
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price.str.replace('$','').astype(float).mean()
# Out:
# 7.464335785374397

# %% [markdown]
# Burada  öncelikle  bilgilerin fiyat bilgisininönündeki dolar isareti order.item_price.str.replace('$','') degistirilir  ve daha sonra  yukaridaki fonksiyona nun object olan tipi aytype(float) degistirilir ve sonra .mean() ortalama degeri  bulunur

# %%
orders.item_name.str.contains('Chicken').head().astype(int)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: item_name, dtype: int32

# %% [markdown]
# Yukarida yapilan islemde stringen olarak tanimladigimiz true  false lari bilgisayar diline cevirdik

# %% [markdown]
# # When should I use '' grouphy'' in pandas?

# %%
import pandas as pd

# %%
drinks =pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent== 'Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').wine_servings.min()
# Out:
# continent
# Africa           0
# Asia             0
# Europe           0
# North America    1
# Oceania          0
# South America    1
# Name: wine_servings, dtype: int64

# %%
drinks.groupby('continent').wine_servings.max()
# Out:
# continent
# Africa           233
# Asia             123
# Europe           370
# North America    100
# Oceania          212
# South America    221
# Name: wine_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['count','max','min','mean'])
# Out:
#                count  max  min        mean
# continent
# Africa            53  376    0   61.471698
# Asia              44  247    0   37.045455
# Europe            45  361    0  193.777778
# North America     23  285    1  145.434783
# Oceania           16  306    0   89.687500
# South America     12  333   93  175.083333

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')

# %%
drinks.groupby('continent').beer_servings.agg(['count','max','min','mean']).plot(kind='bar')

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %% [markdown]
# # How do I explore a Pandas Series?

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')
movie=pd.read_csv('http://bit.ly/imdbratings')
movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movie.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')
# %matplotlib inline

movie.genre.value_counts().plot(kind='bar')

# %%
movie.genre.value_counts(normalize=True).plot(kind='bar') #percentage

# %%
movie.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movie.genre.nunique()
# Out:
# 16

# %%
movie.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
# 120    18
# 105    18
# 126    18
# 98     18
# 130    18
# 100    17
# 121    17
# 116    17
# 124    16
# 122    16
# 118    16
# 115    16
# 96     16
# 104    16
# 110    16
# 107    16
# 109    16
# 119    15
# 114    15
# 99     15
# 108    15
# 94     14
# 117    14
# 106    14
# 93     14
#        ..
# 70      1
# 69      1
# 67      1
# 66      1
# 242     1
# 238     1
# 195     1
# 229     1
# 224     1
# 220     1
# 216     1
# 212     1
# 207     1
# 205     1
# 202     1
# 201     1
# 200     1
# 194     1
# 159     1
# 193     1
# 187     1
# 186     1
# 184     1
# 183     1
# 182     1
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
# %matplotlib inline 
movie.duration.plot(kind='bar')

# %%
movie.genre.value_counts().plot(kind='bar')

# %% [markdown]
# # How do I handle missing value in pandas

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo[ufo.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
ufo.City.isnull().shape
# Out:
# (18241,)

# %%
ufo.dropna(how='any').shape
# Out:
# (2486, 5)

# %% [markdown]
# # Drop yapma

# %%
ufo.dropna(subset=['City','Shape Reported'], how='any').shape
# Out:
# (15576, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %% [markdown]
# # What do i need  to knoiw about pandas index?

# %%
import pandas as pd

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks[drinks.country=='Afghanistan']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia

# %%
drinks.beer_servings.head()
# Out:
# country
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
bouleans=[]
for a in drinks.beer_servings:
    if a >= 100:
        bouleans.append(True)
    else:
        bouleans.append(False)

# %%
bouleans[0:5]
# Out:
# [False, False, False, True, True]

# %%
bool=pd.Series(bouleans)

# %%
bool.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
drinks[bool].beer_servings.head()
# Out:
# country
# 3    245
# 4    217
# 5    102
# 6    193
# 8    261
# Name: beer_servings, dtype: int64

# %%
drop.drinks(axis=1),'index').head()
# Out:
#   File "<ipython-input-65-6240af1d5144>", line 1
#     drop.drinks(axis=1),'index').head()
#                                ^
# SyntaxError: invalid syntax

# %%
drinks.index.name=None
drinks.head()
# Out:
#    index      country  beer_servings  spirit_servings  wine_servings  \
# 0      0  Afghanistan              0                0              0
# 1      1      Albania             89              132             54
# 2      2      Algeria             25                0             14
# 3      3      Andorra            245              138            312
# 4      4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index.name=('country')
drinks.head()
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# 0                    0                0              0
# 1                   89              132             54
# 2                   25                0             14
# 3                  245              138            312
# 4                  217               57             45
#
#          total_litres_of_pure_alcohol continent
# country
# 0                                 0.0      Asia
# 1                                 4.9    Europe
# 2                                 0.7    Africa
# 3                                12.4    Europe
# 4                                 5.9    Africa

# %%
drinks.reset_index(inplace=True)
drinks.head()
# Out:
#    index  beer_servings  spirit_servings  wine_servings  \
# 0      0              0                0              0
# 1      1             89              132             54
# 2      2             25                0             14
# 3      3            245              138            312
# 4      4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
import pandas as pd
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('country',axis=1, inplace=True)

# %%
drinks.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['quantity_of_alchol']=drinks.beer_servings + drinks.total_litres_of_pure_alcohol
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent  quantity_of_alchol
# 0                           0.0      Asia                 0.0
# 1                           4.9    Europe                93.9
# 2                           0.7    Africa                25.7
# 3                          12.4    Europe               257.4
# 4                           5.9    Africa               222.9

# %%
drinks.drop('quantity_of_alchol',axis=1,inplace=True)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# %matplotlib inline
drinks.groupby('continent').beer_servings.mean().plot(kind='barh',stacked=True)

# %%
import pandas as pd

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks[drinks.continent== 'South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
drinks.set_index ('beer_servings',inplace=True)

# %%
drinks.head()
# Out:
#                spirit_servings  wine_servings  total_litres_of_pure_alcohol  \
# beer_servings
# 0                            0              0                           0.0
# 89                         132             54                           4.9
# 25                           0             14                           0.7
# 245                        138            312                          12.4
# 217                         57             45                           5.9
#
#               continent
# beer_servings
# 0                  Asia
# 89               Europe
# 25               Africa
# 245              Europe
# 217              Africa

# %%
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#    index  beer_servings  spirit_servings  wine_servings  \
# 0      0              0                0              0
# 1      1             89              132             54
# 2      2             25                0             14
# 3      3            245              138            312
# 4      4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
import pandas as pd 
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('country',axis=1,inplace=True)

# %%
drinks.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.index.name='country'

# %%
drinks.head()
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# 0                    0                0              0
# 1                   89              132             54
# 2                   25                0             14
# 3                  245              138            312
# 4                  217               57             45
#
#          total_litres_of_pure_alcohol continent
# country
# 0                                 0.0      Asia
# 1                                 4.9    Europe
# 2                                 0.7    Africa
# 3                                12.4    Europe
# 4                                 5.9    Africa

# %%
import pandas as pd

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.set_index('country',inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.loc['Angola','beer_servings']
# Out:
# 217

# %%
drinks.index.name=None
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index.name='country'

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.reset_index(inplace=True)
drinks.head()
# Out:
#    index      country  beer_servings  spirit_servings  wine_servings  \
# 0      0  Afghanistan              0                0              0
# 1      1      Albania             89              132             54
# 2      2      Algeria             25                0             14
# 3      3      Andorra            245              138            312
# 4      4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.describe()
# Out:
#             index  beer_servings  spirit_servings  wine_servings  \
# count  193.000000     193.000000       193.000000     193.000000
# mean    96.000000     106.160622        80.994819      49.450777
# std     55.858452     101.143103        88.284312      79.697598
# min      0.000000       0.000000         0.000000       0.000000
# 25%     48.000000      20.000000         4.000000       1.000000
# 50%     96.000000      76.000000        56.000000       8.000000
# 75%    144.000000     188.000000       128.000000      59.000000
# max    192.000000     376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe().columns
# Out:
# Index(['index', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
drinks.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %% [markdown]
# # What  do I do know about(Part 2)

# %%
import pandas as pd 
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.set_index('country', inplace=True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
people=pd.Series([30000000,8500], ['Albanien','sandora'],name='Population')
people
# Out:
# Albanien    30000000
# sandora         8500
# Name: Population, dtype: int64

# %%
drinks.beer_servings*people
# Out:
# Afghanistan            NaN
# Albania                NaN
# Albanien               NaN
# Algeria                NaN
# Andorra                NaN
# Angola                 NaN
# Antigua & Barbuda      NaN
# Argentina              NaN
# Armenia                NaN
# Australia              NaN
# Austria                NaN
# Azerbaijan             NaN
# Bahamas                NaN
# Bahrain                NaN
# Bangladesh             NaN
# Barbados               NaN
# Belarus                NaN
# Belgium                NaN
# Belize                 NaN
# Benin                  NaN
# Bhutan                 NaN
# Bolivia                NaN
# Bosnia-Herzegovina     NaN
# Botswana               NaN
# Brazil                 NaN
# Brunei                 NaN
# Bulgaria               NaN
# Burkina Faso           NaN
# Burundi                NaN
# Cabo Verde             NaN
#                         ..
# Suriname               NaN
# Swaziland              NaN
# Sweden                 NaN
# ...

# %%
pd.concat([drinks,people], axis=1,).head()
# Out:
# C:\Users\sahin\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan            0.0              0.0            0.0
# Albania               89.0            132.0           54.0
# Albanien               NaN              NaN            NaN
# Algeria               25.0              0.0           14.0
# Andorra              245.0            138.0          312.0
#
#              total_litres_of_pure_alcohol continent  Population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe         NaN
# ...

# %% [markdown]
# # How do I select multiple rows and columns from pandas Dataframe?

# %%
import pandas as pd
ufos=pd.read_csv('http://bit.ly/uforeports')

# %%
ufos.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufos.loc[0, : ]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
ufos.loc[[0,1,2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufos.loc[0:2,]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufos.loc[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufos.loc[:,['City']].head(2)
# Out:
#           City
# 0       Ithaca
# 1  Willingboro

# %%
ufos.loc[:,'City'].head(2)
# Out:
# 0         Ithaca
# 1    Willingboro
# Name: City, dtype: object

# %%
ufos.loc[:,['City','State']].head(5)
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufos.head(3).drop('Time', axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufos[ufos.City=='Ithaca']
# Out:
#          City Colors Reported Shape Reported State              Time
# 0      Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 4068   Ithaca             NaN          CIGAR    NY    6/1/1979 19:00
# 5631   Ithaca             NaN          OTHER    MI    6/1/1987 17:00
# 6961   Ithaca             NaN          OTHER    NY    1/10/1993 0:30
# 7573   Ithaca       RED GREEN          LIGHT    NY  10/15/1994 18:00
# 9088   Ithaca             NaN            NaN    NY   2/16/1996 21:45
# 16537  Ithaca             NaN          FLASH    MI    6/3/2000 22:35
# 17049  Ithaca             NaN       TEARDROP    NY   7/30/2000 20:20
